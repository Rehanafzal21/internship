# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %%
task_type = "ranking"
reason = (
    "I want to rank webpages by decline risk so I can focus on the ones "
    "that need attention first."
)
print(f"task_type: {task_type}")
print(f"reason: {reason}")
# Out:
# task_type: ranking
# reason: I want to rank webpages by decline risk so I can focus on the ones that need attention first.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %%
print("We will predict the decline risk of a webpage based on its features and historical performance. The label is a proxy label created from observed impression data. It is a defined rule based on observed data.")
# Out:
# We will predict the decline risk of webpage based on the features
# of the webpage and its historical performance. The label is a proxy
# label created from observed impression data. It is a
# defined rule, based on observed data.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %%
success_metric = "Precision@50"
reason = (
    "A good ranking should place truly declining pages near the top of the review queue."
)

good_number = "better than the baseline"
reason1 = (
    "A good model should have a Precision@50 that is clearly above a simple rule or random ranking."
)
print("success metric::", success_metric)
print(reason)
print("good number::", good_number)
print(reason1)
# Out:
# success metric:: Precision@50
# A good ranking should place truly declining pages near the top of the review queue.
# good number:: better than the baseline
# A good model should have a Precision@50 that is clearly above a simple rule or random ranking.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
from pathlib import Path
import pandas as pd

repo_root = Path.cwd()
if not (repo_root / "data/raw/content_refresh_anonymized.csv").exists():
    repo_root = repo_root.parent.parent

path = repo_root / "data/raw/content_refresh_anonymized.csv"
df = pd.read_csv(path)

print("Rows:", len(df))
print("Columns:", len(df.columns))
print("One row = one webpage/content item")
df.head(1)
# Out:
# Rows: 30000
# Columns: 44
# One row = one webpage/content item
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
#
#    char_count  ... char_count_tier   ctr  avg_position  engagement_rate  \
# 0     20457.0  ...     15000-25000  0.76          10.6             5.88
#
#    scroll_rate  ai_traffic_pct  impression_tier  position_tier  \
# 0         4.55             0.0             good       striking
#
#    trend_direction  trend_pct
# 0             down      -41.4
#
# [1 rows x 44 columns]

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %%
print("I am predicting whether a webpage is likely to decline by using its past signals and history. A simple fixed if-statement is too rigid because the pattern is noisy and depends on many signals, not one clear rule.")
# Out:
# I was predicting the decline of webpage on the basis of past
# data.To predict that i have to train a model then made a fixed
# rule on the basis of observed output. so a simle fixed if
# statement cant do this without observed data and can result in
# wrong prediction.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom without obvious errors
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, and decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
